# %% [markdown]
# ## Installing Necessary Libraries

# %%
# !pip install -q -U trl transformers accelerate git+https://github.com/huggingface/peft.git
# !pip install -q datasets bitsandbytes einops wandb
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.0/118.0 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 78.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 29.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 39.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 13.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 66.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 48.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.5 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 67.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 23.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 27.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.0 MB/s eta 0:00:00
#   Building wheel for pathtools (setup.py) ... done

# %% [markdown]
# # Dataset details
# Instacart Data can be downloaded from [here](https://www.kaggle.com/competitions/instacart-market-basket-analysis/data). We just need product & department csv files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/'Colab Notebooks'
# Out:
# '202111035_assignment3 (2).ipynb'
# 'Accuracy Benchmarks on PENS.ipynb'
# 'Accuracy Benchmarks on PENS P-Meteor.ipynb'
#  Asg2_DL_final.ipynb
#  Asg3.ipynb
#  Asg5.ipynb
#  Assignment_1_DL.ipynb
# 'Copy of 07.falcon-qlora-fine-tuning.ipynb'
# 'Copy of Fake_Profile_Identifier.ipynb'
# 'Copy of Fine-tune a language model'
# 'Copy of Index.ipynb'
# 'Copy of Llama2 finetuning on Instacart Dataset'
# 'Copy of Llama2 finetuning on Instacart Dataset (1)'
# 'Copy of NLP_A1.ipynb'
# 'Final ML Assignment_1 202111035.ipynb'
# 'Llama2 finetuning on Instacart Dataset'
#  ML_LA3.ipynb
# 'model ranking for edins.ipynb'
# 'model ranking for p_acc.ipynb'
#  Movielens20mDataset
#  MTech
# 'new correlation for dev-acc vs dev-ins.ipynb'
#  NLP2_035.ipynb
#  peft
#  peft-1692644044
#  peft-1692644617
#  peft-dialogue-summary-checkpoint-local
# 'Personalization Benchmark on PENS.ipynb'
# 'Personalization vs Accuracy Ranking Agreement.ipynb'
# 'replace jsd with other acc measures in edins.ipynb'
#  SDego
#  Untitled
#  Untitled0.ipynb
#  Untitled1.ipynb

# %%
import pandas as pd
path= '/content/drive/MyDrive/Colab Notebooks/Llama2 finetuning on Instacart Dataset/'
df_product = pd.read_csv(path+"products.csv")
df_dept = pd.read_csv(path+'departments.csv')

# %%
df_joined = pd.merge(df_product, df_dept, on = ['department_id'])
df_joined['text'] = df_joined.apply(lambda row: row['product_name'] + " ->: " + row['department'], axis = 1)

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(df_joined, test_size=0.2, random_state=42)

# %%
train_df.head(10)
# Out:
#        product_id                                       product_name  \
# 7361        10376                              Organic Caraway Seeds
# 32534       40131                         Original Laundry Detergent
# 1457        11913                                 Shelled Pistachios
# 5201        41392                   Harvest Berry Chewy Granola Bars
# 38539       28627              Veganic Sprouted Red Fife Raisin Bran
# 18377       29407                               Root Vegetable Cakes
# 28627       29571                                  Alta Dena 1% Milk
# 30283        3589                             Laundry Detergent Pods
# 32030       31685  Daily Shower Cleaner Scrub Free Refill, Fresh ...
# 28655       30119            Organic French Style Meyer Lemon Yogurt
#
#        aisle_id  department_id  department  \
# 7361        104             13      pantry
# 32534        75             17   household
# 1457        117             19      snacks
# 5201          3             19      snacks
# 38539       121             14   breakfast
# 18377        42              1      frozen
# 28627        84             16  dairy eggs
# 30283        75             17   household
# 32030       114             17   household
# 28655       120             16  dairy eggs
#
#                                                     text
# 7361                    Organic Caraway Seeds ->: pantry
# 32534           Original Laundry Detergent ->: household
# 1457                       Shelled Pistachios ->: snacks
# 5201         Harvest Berry Chewy Granola Bars ->: snacks
# 38539  Veganic Sprouted Red Fife Raisin Bran ->: brea...
# 18377                    Root Vegetable Cakes ->: frozen
# 28627                   Alta Dena 1% Milk ->: dairy eggs
# 30283               Laundry Detergent Pods ->: household
# 32030  Daily Shower Cleaner Scrub Free Refill, Fresh ...
# 28655  Organic French Style Meyer Lemon Yogurt ->: da...

# %%
test_df.head(10)
# Out:
#        product_id                                       product_name  \
# 33626       24154             Free & Clear Stage 4 Overnight Diapers
# 18192       27348  Beef pot roast with roasted potatoes, carrots,...
# 47099       27181                                      Coffee Liquer
# 48183       20577                                        Bread Rolls
# 22197       16472           French Milled Oval Almond Gourmande Soap
# 31573       24121                                           Dust Pan
# 45362        5477                            Roasted Pine Nut Hommus
# 14131       27921                 Cranberry Raspberry Juice Cocktail
# 26903        4786                          Sweet Cream Butter Salted
# 39417        8796                    Traditional Chicken Barley Soup
#
#        aisle_id  department_id     department  \
# 33626        56             18         babies
# 18192        38              1         frozen
# 47099       124              5        alcohol
# 48183        43              3         bakery
# 22197        25             11  personal care
# 31573       114             17      household
# 45362        67             20           deli
# 14131        98              7      beverages
# 26903        36             16     dairy eggs
# 39417        69             15   canned goods
#
#                                                     text
# 33626  Free & Clear Stage 4 Overnight Diapers ->: babies
# 18192  Beef pot roast with roasted potatoes, carrots,...
# 47099                          Coffee Liquer ->: alcohol
# 48183                             Bread Rolls ->: bakery
# 22197  French Milled Oval Almond Gourmande Soap ->: p...
# 31573                             Dust Pan ->: household
# 45362                   Roasted Pine Nut Hommus ->: deli
# 14131   Cranberry Raspberry Juice Cocktail ->: beverages
# 26903           Sweet Cream Butter Salted ->: dairy eggs
# 39417   Traditional Chicken Barley Soup ->: canned goods

# %%
from datasets import Dataset,DatasetDict
train_dataset_dict = DatasetDict({
    "train": Dataset.from_pandas(train_df),
})

# %% [markdown]
# ## Loading the model

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, AutoTokenizer

model_name = "TinyPixel/Llama-2-7B-bf16-sharded"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    trust_remote_code=True
)
model.config.use_cache = False
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/626 [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/14 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00014.bin:   0%|          | 0.00/981M [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00003-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00004-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)l-00005-of-00014.bin:   0%|          | 0.00/944M [00:00<?, ?B/s]
# Downloading (…)l-00006-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)l-00007-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00008-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00009-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)l-00010-of-00014.bin:   0%|          | 0.00/944M [00:00<?, ?B/s]
# Downloading (…)l-00011-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)l-00012-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00013-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00014-of-00014.bin:   0%|          | 0.00/847M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/14 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %% [markdown]
# Let's also load the tokenizer below

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/676 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/411 [00:00<?, ?B/s]

# %% [markdown]
# **Let's check what the base model predicts before finetuning. :)**

# %%
import transformers
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
)


sequences = pipeline(
   ["“Free & Clear Stage 4 Overnight Diapers” ->:","Bread Rolls ->:","French Milled Oval Almond Gourmande Soap ->:"],
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq[0]['generated_text']}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1417: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# Result: “Free & Clear Stage 4 Overnight Diapers” ->:
#  everybody who’s not a child is now a child
# the only “free” thing about it is the “4”
# you’re going for 1995 and it’s 2013 and we all know the internet is the best way to advertise a product
# but you have to have your own computer
# and the internet has no interest in “Free and Clear Stage 4 Overnight Diapers”
# because the internet is all about the “Free & Clear”
# and there’s nothing “Free & Clear” about “Stage 4 Overnight Diapers”
# because “Stage 4 Overnight Diapers” is not a thing that exists
# the only thing that’s “Free & Clear” is
# and that’s not a thing that exists
# so what’s the best way to advertise the product that’s called
#
# Result: Bread Rolls ->:D 07-24-2020 05:19 PM
# Result: French Milled Oval Almond Gourmande Soap ->: https://www. фев 2009 6:31 UTC. It is a small piece of cake, which is covered by white chocolate and topped. com has 0 reviews of Cake Mix Bakery with phone number, address, hours of operation and more. A wide range of traditional cakes, including a selection from the bakery in the heart of Paris and a variety of delicious dessert trays, are also offered. 02008 715 594. A small piece of cake, which is covered by white chocolate and topped. 17000 Cake Shop jobs available on Indeed. com 2009-11-24. The cake was moist, with great taste and the icing was perfect and the decorations very cute. The shop

# %% [markdown]
# Below we will load the configuration file in order to create the LoRA model. According to QLoRA paper, it is important to consider all linear layers in the transformer block for maximum performance.

# %% [markdown]
# # finetuning with rank 10

# %%
from peft import LoraConfig

lora_alpha = 16
lora_dropout = 0.1
lora_r = 10 #64

peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["q_proj","v_proj"]
)

# %% [markdown]
# ## Loading the trainer

# %% [markdown]
# Here we will use the [`SFTTrainer` from TRL library](https://huggingface.co/docs/trl/main/en/sft_trainer) that gives a wrapper around transformers `Trainer` to easily fine-tune models on instruction based datasets using PEFT adapters. Let's first load the training arguments below.

# %%
from transformers import TrainingArguments

output_dir = "./results"
per_device_train_batch_size = 4
gradient_accumulation_steps = 4
optim = "paged_adamw_32bit"
save_steps = 10
logging_steps = 1
learning_rate = 2e-4
max_grad_norm = 0.3
max_steps = 120
warmup_ratio = 0.03
lr_scheduler_type = "constant"

training_arguments = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    fp16=True,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=True,
    lr_scheduler_type=lr_scheduler_type,
)

# %% [markdown]
# Then finally pass everthing to the trainer

# %%
from trl import SFTTrainer

max_seq_length = 512

trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset_dict['train'],
    # train_dataset=data['train'],
    peft_config=peft_config,
    dataset_text_field="text",
    # dataset_text_field="prediction",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:133: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# Map:   0%|          | 0/39750 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:207: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(

# %% [markdown]
# We will also pre-process the model by upcasting the layer norms in float 32 for more stable training

# %%
for name, module in trainer.model.named_modules():
    if "norm" in name:
        module = module.to(torch.float32)

# %% [markdown]
# ## Train the model

# %% [markdown]
# Now let's train the model! Simply call `trainer.train()`

# %%
trainer.train()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.15.11
# Run data is saved locally in <code>/content/wandb/run-20230926_181903-4xzuy4dv</code>
# Syncing run <strong><a href='https://wandb.ai/rahulvansh66/huggingface/runs/4xzuy4dv' target="_blank">smooth-surf-2</a></strong> to <a href='https://wandb.ai/rahulvansh66/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/rahulvansh66/huggingface' target="_blank">https://wandb.ai/rahulvansh66/huggingface</a>
#  View run at <a href='https://wandb.ai/rahulvansh66/huggingface/runs/4xzuy4dv' target="_blank">https://wandb.ai/rahulvansh66/huggingface/runs/4xzuy4dv</a>
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='120' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [120/120 06:27, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.029100</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.089600</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.359200</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.271200</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.250100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.093100</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.518600</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.971700</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>4.474900</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>5.364800</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>4.251900</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>4.126000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>6.116300</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>4.124900</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>4.050200</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>3.913600</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>4.863700</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>3.831800</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>3.773300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>3.636200</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>3.266500</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>4.369100</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>3.306000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>3.094400</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>2.982100</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>4.245400</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>3.106400</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>2.572800</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>2.667000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.497800</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.829200</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>2.350700</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>2.648000</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>3.785000</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>2.443000</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>2.478200</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>2.244400</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>2.447100</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>2.512700</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.119000</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>2.320300</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>2.185200</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>2.191800</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>2.027000</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>2.097500</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>3.231500</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>2.323600</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>3.867900</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>2.430900</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>3.045300</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.725400</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.723500</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>2.459500</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>3.051100</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>3.960600</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>2.531700</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1.465900</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>2.220300</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>2.359600</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>2.168700</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>2.266500</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>1.517100</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>2.153400</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>1.760500</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>2.025800</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>2.108700</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>2.001800</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>1.569700</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>2.045700</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>2.305900</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>3.960900</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>1.940700</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>1.818300</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>2.092100</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>2.212200</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>2.235200</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>2.160500</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>2.322100</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>2.216700</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>2.207100</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>2.022800</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>1.962000</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>2.070100</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>2.159200</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>2.833100</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>2.218700</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>2.063500</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>1.917200</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>1.955700</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>2.875700</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>2.005200</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>1.992200</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>2.065900</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>2.495300</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>2.113400</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>2.127200</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>2.410800</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>2.184600</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>2.443400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>4.787400</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>3.142700</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>2.272600</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>2.240800</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>2.467800</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>2.023400</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>2.539000</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>2.123000</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>2.332300</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>2.173800</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>2.230000</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>2.222000</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>3.073600</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>1.845300</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>2.301000</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>2.343100</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>2.963800</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>1.996900</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>2.004000</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>2.202300</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>2.134900</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=120, training_loss=2.705991934239864, metrics={'train_runtime': 573.3223, 'train_samples_per_second': 3.349, 'train_steps_per_second': 0.209, 'total_flos': 622084277501952.0, 'train_loss': 2.705991934239864, 'epoch': 0.05})

# %%
lst_test_data = list(test_df['text'])

# %%
len(lst_test_data)
# Out:
# 9938

# %%
sample_size = 25
lst_test_data_short = lst_test_data[:sample_size]

# %%
import transformers

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    # torch_dtype=torch.bfloat16,
    torch_dtype=torch.float16,
    trust_remote_code=True,
    device_map="auto",
)

sequences = pipeline(
    lst_test_data_short,
    max_length=100,  #200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)

for ix,seq in enumerate(sequences):
    print(ix,seq[0]['generated_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:31: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# 0 Free & Clear Stage 4 Overnight Diapers ->: babies toddlers: diapers: free & clear overnight diapers ->: household products: cleaners: toilet care: toilet paper: diapers ->: household products: cleaners: toilet care: toilet paper items: diapers: free & clear stage 4 overnight diapers: free & clear overnight diapers: household products: cleaners: toilet
# 1 Beef pot roast with roasted potatoes, carrots, sweet onions, green beans, and a rich gravy Beef Pot Roast ->: frozen products ->: meat and fish ->: beef & pork ->: meat products ->: beef ->: frozen ->: beef pot roast with roasted potatoes, carrots, sweet onions, green beans, and a rich gravy ->: personal size ->: personal size
# 2 Coffee Liquer ->: alcohol ->: liqueurs ->: liqueur flavored drinks ->: other coffee flavor ->: coffee liquers coffee flavor ->: coffee ->: coffee ->: coffee liquers ->: coffee flavor coffee liquers ->: ice coffee cream ->: ice cream ->: ice cream ->: non dairy ->: coffee ->: coffee beans ->: iced coffee ->: non dairy ->: coffee beans
# 3 Bread Rolls ->: bakery ->: snacks ->: breakfast pastries ->: pasteries ->: frozen pastries ->: snacks ->: frozen breads ->: frozen snack breads ->: frozen breads, pastries & snacks ->: frozen snack breads ->: frozen snack breads ->: frozen breakfast pastries ->: frozen breakfast pastries ->: frozen frosted pastries ->: fro
# 4 French Milled Oval Almond Gourmande Soap ->: personal care toilet soap: personal care products ->: toiletries: body care products ->: toiletries: body soaps & hand cleaners ->: toiletries: dish cleaners & soaps ->: toiletries: soaps ->: household: soap ->: household: soap & cleaner items: household cleaners: all-purpose soap products: cleaning supplies:
# 5 Dust Pan ->: household: cleaning ->: cleaning brushes ->: household: dust brushes ->: household: brooms, dusters: dust pan: bags & Accessories ->: household: brooms, dusters: dust pan: dusting: dusters ->: household: brooms, dusters: dust pan: dusting: dusting: duster: feather Duster ->: household: brooms, dusters: dust pan: dust
# 6 Roasted Pine Nut Hommus ->: deli meat & cheese ->: deli meat ->: deli cold cuts ->: turkish deli ->: pine nut hommus ->: deli meat ->: deli cold cuts ->: turkish deli ->: pine nut hommus ->: deli meat ->: deli cold cuts ->: turkish deli ->: pine nut hommus ->: deli meat ->: deli cold cuts ->:
# 7 Cranberry Raspberry Juice Cocktail ->: beverages and mixes ->: juice beverages ->: drinks ->: beverages ->: cranberry ->: juices and juice drinks ->: fruit juices ->: fruit juice cocktails ->: cranberry raspberry juice cocktail ->: snacks ->: snack foods ->: juices and juice drinks ->: beverages
# 8 Sweet Cream Butter Salted ->: dairy eggs & dairy products eggs butter ->: butter products butter ->: butter & margarine butter products butter ->: butter salted ->: dairy dairy products eggs ->: eggs butter products eggs ->: eggs eggs ->: eggs butter ->: butter products eggs ->: eggs ->: eggs butter eggs eggs & dairy products ->: eggs ->: dairy products ->:
# 9 Traditional Chicken Barley Soup ->: canned goods ->: soups ->: chicken ->: classic canned chicken soups ->: traditional chicken barley soup: chicken barley original ->: pantry & starches ->: pantry products: soup ->: canned goods ->: soups ->: chicken: traditional chicken barley soup: chicken barley original ->: pantry & starches ->: pantry products: soup
# 10 Vanilla Unsweetened Cashewmilk ->: dairy eggs eggs eggs ->: dairy eggs dairy products ->: dairy ice cream frozen ->: dairy ice cream frozen cream ->: dairy ice cream frozen ->: dairy ice cream ice cream ->: dairy ice cream ->: dairy milk ->: dairy ice cream ->: dairy ->: dairy milk eggs ->: dairy eggs da
# 11 Minis Size Chocolate Candy Bars Variety Mix ->: snacks ->: candies ->: chocolates ->: dark ->: dark chocolate bars ->: chocolates ->: dark chocolate bars ->: dark chocolate bars ->: dark ->: dark chocolate bars ->: chocolates ->: chocolates ->: candy ->: candy bars ->: chocolates ->: dark chocolate
# 12 Cheesy Cheddar Rotini Pasta Sides ->: dry goods pasta ->: pasta ->: pasta sides ->: pasta sides ->: pasta sides ->: pasta sides ->: pasta sides, cheesy cheddar ->: pasta ->: pasta ->: pasta side ->: pasta pasta ->: dry goods pasta ->: pasta ->: pasta sides ->: pasta sides ->: pasta sides ->:
# 13 Multi Purpose Solution ->: personal care ->: personal hygiene ->: personal wash ->: baby ->: wash ->: liquid wash with lotion: baby: purple liquid wash ->: household: laundry detergent ->: laundry detergents ->: wash ->: detergents ->: laundry detergent, dishwashing liquid ->: household cleaning ->: household cleaning supplies ->: d
# 14 Juice, Raw & Cold-Pressed, Purity ->: beverages ->: juice, smoothies & dairy substitutes ->: beverages ->: dairy substitutes ->: juice ->: organic ->: beverages ->: juice, smoothies & dairy substitutes ->: beverages ->: juice, smoothies & dairy substitutes ->: organic ->: organic juice ->: raw & cold
# 15 Chinese Five Spices Powder ->: international pantry ->: spices ->: dry goods ->: chinese five spices powder: international pantry spices dry goods chinese five spices powder ->: international pantry ->: spices ->: dry goods ->: chinese five spices pantry ->: international pantry ->: spices ->: dry goods ->: chinese five spices: international pantry spices pantry ->: international pantry ->:
# 16 Ancient Grain Original Granola ->: breakfast ->: cereals ->: oat products ->: granola ->: ancient grains original ->: breakfast ->: oat products ->: granola ->: ancient grains original granola ->: breakfast ->: cereals ->: oat products ->: granola ->: original organic ->: cereal ->: granola ->: original ->: granola ->: original organic ->: breakfast cereals ->
# 17 Crunch Lemon Shortbread Flavor 0% Fat with Toppings Greek Yogurt ->: dairy eggs eggs ->: dairy eggs ->: eggs ->: eggs ->: pantry pasta sauces & dressings ->: sauces & dressings ->: sauces ->: sauces & dressings ->: condiments ->: sauces ->: pasta sauces & dressings ->: pantry ->: eggs pantry items ->: condiments ->
# 18 Flounder Fillets ->: meat seafood ->: seafood ->: fish ->: seafood ->: flounder ->: flounder fillets ->: fish ->: flounder fillets ->: flounder fillets ->: seafood ->: fish ->: flounder fillets chicken breast pouches ->: meat seafood ->: seafood ->: fish ->: flounder fillets chicken breast pouch
# 19 Lilac Votive ->: household cleaning products ->: cleaners & sprays ->: household cleaners ->: laundry cleaners ->: laundry cleaners ->: liquid detergent ->: laundry cleaners ->: laundry powder ->: laundry cleaners ->: stain removers ->: household cleaners ->: laundry cleaners ->: dish detergent ->: laundry cleaners ->:
# 20 Cheese & Broccoli Ravioli For Kids ->: frozen foods ->: pasta ->: pasta & ravioli ->: pasta & noodles ->: frozen pasta ->: pasta ->: frozen pasta ->: pastas ->: pastas ->: ravioli ->: cheese ->: cheese ->: cheese ->: cheese ->: cheese & broccoli ->: cheese & broccoli ra
# 21 Organic Soymilk Original Value Size ->: dairy eggs & cheese eggs ->: dairy eggs pasta egg ->: dairy eggs pasta egg ->: dairy eggs pasta eggs ->: dairy eggs ->: dairy egg pasta ->: dairy dairy pasta ->: organic eggs ->: organic pasta ->: organic pasta & noodles ->: pasta ->: organic pasta ->: pasta ->: past
# 22 Fruit Juice Sweetened Millet Rice Cereal ->: breakfast ->: baby foods & snacks ->: baby foods: fruit & vegetables ->: fruit & vegetable cereals ->: cereal ->: fruit juice ->: sweetened milk ->: organic juice ->: organic cereal ->: sweetened baby cereal ->: sweetened organic cereal ->: organic cereal
# 23 Morning Burst® Facial Scrub Cleansers ->: personal care ->: skin care ->: skin care cleaners ->: exfoliators ->: cleansers ->: morning burst ->: morning burst facial scrub cleansers morning burst facial scrub cleansers ->: facial scrub cleansers ->: morning burst facial scrub cleansers ->: morning burst facial wash morning burst facial wash ->: cleans
# 24 Salmon Pinwheels ->: meat seafood ->: seafood ->: frozen seafood ->: seafood appetizers: snack tray ->: snacks ->: snack trays ->: frozen seafood snacks ->: seafood snacks ->: fish ->: frozen seafood ->: seafood snacks ->: fish ->: wild salmon snacks ->: seafood snacks ->:

# %%
def correct_answer(ans):
  return (ans.split("->:")[1]).strip()

answers = []
for ix,seq in enumerate(sequences):
    # print(ix,seq[0]['generated_text'])
    answers.append(correct_answer(seq[0]['generated_text']))

answers
# Out:
# ['babies toddlers: diapers: free & clear overnight diapers',
#  'frozen products',
#  'alcohol',
#  'bakery',
#  'personal care toilet soap: personal care products',
#  'household: cleaning',
#  'deli meat & cheese',
#  'beverages and mixes',
#  'dairy eggs & dairy products eggs butter',
#  'canned goods',
#  'dairy eggs eggs eggs',
#  'snacks',
#  'dry goods pasta',
#  'personal care',
#  'beverages',
#  'international pantry',
#  'breakfast',
#  'dairy eggs eggs',
#  'meat seafood',
#  'household cleaning products',
#  'frozen foods',
#  'dairy eggs & cheese eggs',
#  'breakfast',
#  'personal care',
#  'meat seafood']

# %%
df_evaluate = test_df.iloc[:sample_size][['product_name','department']]

df_evaluate = df_evaluate.reset_index(drop=True)

df_evaluate['department_predicted'] = answers

df_evaluate
# Out:
#                                          product_name       department  \
# 0              Free & Clear Stage 4 Overnight Diapers           babies
# 1   Beef pot roast with roasted potatoes, carrots,...           frozen
# 2                                       Coffee Liquer          alcohol
# 3                                         Bread Rolls           bakery
# 4            French Milled Oval Almond Gourmande Soap    personal care
# 5                                            Dust Pan        household
# 6                             Roasted Pine Nut Hommus             deli
# 7                  Cranberry Raspberry Juice Cocktail        beverages
# 8                           Sweet Cream Butter Salted       dairy eggs
# 9                     Traditional Chicken Barley Soup     canned goods
# 10                     Vanilla Unsweetened Cashewmilk       dairy eggs
# 11        Minis Size Chocolate Candy Bars Variety Mix           snacks
# 12                  Cheesy Cheddar Rotini Pasta Sides  dry goods pasta
# 13                             Multi Purpose Solution    personal care
# 14                  Juice, Raw & Cold-Pressed, Purity        beverages
# 15                         Chinese Five Spices Powder    international
# 16                     Ancient Grain Original Granola        breakfast
# 17  Crunch Lemon Shortbread Flavor 0% Fat with Top...       dairy eggs
# 18                                   Flounder Fillets     meat seafood
# 19                                       Lilac Votive        household
# 20                 Cheese & Broccoli Ravioli For Kids           frozen
# 21                Organic Soymilk Original Value Size       dairy eggs
# 22           Fruit Juice Sweetened Millet Rice Cereal        breakfast
# 23              Morning Burst® Facial Scrub Cleansers    personal care
# 24                                   Salmon Pinwheels     meat seafood
#
#                                  department_predicted
# 0   babies toddlers: diapers: free & clear overnig...
# 1                                     frozen products
# 2                                             alcohol
# 3                                              bakery
# 4   personal care toilet soap: personal care products
# 5                                 household: cleaning
# 6                                  deli meat & cheese
# 7                                 beverages and mixes
# 8             dairy eggs & dairy products eggs butter
# 9                                        canned goods
# 10                               dairy eggs eggs eggs
# 11                                             snacks
# 12                                    dry goods pasta
# 13                                      personal care
# 14                                          beverages
# 15                               international pantry
# 16                                          breakfast
# 17                                    dairy eggs eggs
# 18                                       meat seafood
# 19                        household cleaning products
# 20                                       frozen foods
# 21                           dairy eggs & cheese eggs
# 22                                          breakfast
# 23                                      personal care
# 24                                       meat seafood

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# !pip install evaluate
# !pip install rouge_score

# %%
# df_evaluate['department_predicted']
import evaluate
rouge = evaluate.load('rouge')
predictions = df_evaluate['department_predicted'].values
references = df_evaluate['department'].values
results = rouge.compute(predictions=predictions, references=references)
print(results)
# Out:
# {'rouge1': 0.7853333333333333, 'rouge2': 0.32476190476190475, 'rougeL': 0.7828888888888887, 'rougeLsum': 0.7786666666666666}
